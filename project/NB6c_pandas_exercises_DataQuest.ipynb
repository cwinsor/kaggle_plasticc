# %% [markdown]
# # Practice with pandas from DataQuest
# https://www.dataquest.io/blog/pandas-python-tutorial/

# %%
import pandas as pd
reviews = pd.read_csv("data_groupby_practice\ign.csv")

# %%
reviews.head(3)
# Out:
#    Unnamed: 0 score_phrase                                              title  \
# 0           0      Amazing                            LittleBigPlanet PS Vita
# 1           1      Amazing  LittleBigPlanet PS Vita -- Marvel Super Hero E...
# 2           2        Great                               Splice: Tree of Life
#
#                                                  url          platform  score  \
# 0             /games/littlebigplanet-vita/vita-98907  PlayStation Vita    9.0
# 1  /games/littlebigplanet-ps-vita-marvel-super-he...  PlayStation Vita    9.0
# 2                          /games/splice/ipad-141070              iPad    8.5
#
#         genre editors_choice  release_year  release_month  release_day
# 0  Platformer              Y          2012              9           12
# 1  Platformer              Y          2012              9           12
# 2      Puzzle              N          2012              9           12

# %%
reviews.shape
# Out:
# (18625, 11)

# %%
reviews.iloc[0:3,:]
# Out:
#    Unnamed: 0 score_phrase                                              title  \
# 0           0      Amazing                            LittleBigPlanet PS Vita
# 1           1      Amazing  LittleBigPlanet PS Vita -- Marvel Super Hero E...
# 2           2        Great                               Splice: Tree of Life
#
#                                                  url          platform  score  \
# 0             /games/littlebigplanet-vita/vita-98907  PlayStation Vita    9.0
# 1  /games/littlebigplanet-ps-vita-marvel-super-he...  PlayStation Vita    9.0
# 2                          /games/splice/ipad-141070              iPad    8.5
#
#         genre editors_choice  release_year  release_month  release_day
# 0  Platformer              Y          2012              9           12
# 1  Platformer              Y          2012              9           12
# 2      Puzzle              N          2012              9           12

# %%
reviews.loc[0:3,['title','release_year']]
# Out:
#                                                title  release_year
# 0                            LittleBigPlanet PS Vita          2012
# 1  LittleBigPlanet PS Vita -- Marvel Super Hero E...          2012
# 2                               Splice: Tree of Life          2012
# 3                                             NHL 13          2012

# %% [markdown]
# # Pandas DataFrame methods

# %%
# what is the mean score?
reviews.loc[:,['score']].mean()
# Out:
# score    6.950459
# dtype: float64

# %%
reviews.mean()
# Out:
# Unnamed: 0       9312.000000
# score               6.950459
# release_year     2006.515329
# release_month       7.138470
# release_day        15.603866
# dtype: float64

# %%
reviews.corr()
# Out:
#                Unnamed: 0     score  release_year  release_month  release_day
# Unnamed: 0       1.000000  0.035579      0.893394      -0.096676     0.010068
# score            0.035579  1.000000      0.062716       0.007632     0.020079
# release_year     0.893394  0.062716      1.000000      -0.115515     0.016867
# release_month   -0.096676  0.007632     -0.115515       1.000000    -0.067964
# release_day      0.010068  0.020079      0.016867      -0.067964     1.000000

# %% [markdown]
# # Boolean indexing

# %%
# Find all the games that got an above-average score?
reviews.loc[:,["score"]].mean()
# Out:
# score    6.950459
# dtype: float64

# %%
filter = reviews['score'] > 6.95
reviews.loc[filter]
# Out:
#        Unnamed: 0 score_phrase  \
# 0               0      Amazing
# 1               1      Amazing
# 2               2        Great
# 3               3        Great
# 4               4        Great
# ...           ...          ...
# 18619       18619         Good
# 18620       18620         Good
# 18621       18621      Amazing
# 18623       18623  Masterpiece
# 18624       18624  Masterpiece
#
#                                                    title  \
# 0                                LittleBigPlanet PS Vita
# 1      LittleBigPlanet PS Vita -- Marvel Super Hero E...
# 2                                   Splice: Tree of Life
# 3                                                 NHL 13
# 4                                                 NHL 13
# ...                                                  ...
# 18619                                    Human Fall Flat
# 18620                          Tokyo Mirage Sessions #FE
# 18621                  LEGO Star Wars: The Force Awakens
# ...

# %%
# Find games released for the Xbox One that have a score of more than 7. 
filter1 = reviews['score'] > 7.
filter2 = reviews['platform'] == 'Xbox One'
reviews[filter1 & filter2]
# Out:
#        Unnamed: 0 score_phrase                     title  \
# 17137       17137      Amazing                 Gone Home
# 17197       17197      Amazing            Rayman Legends
# 17295       17295      Amazing  LEGO Marvel Super Heroes
# 17313       17313        Great             Dead Rising 3
# 17317       17317        Great           Killer Instinct
# ...           ...          ...                       ...
# 18582       18582        Great                       Fru
# 18588       18588        Great                   F1 2016
# 18591       18591      Amazing  Deus Ex: Mankind Divided
# 18602       18602         Good         Hitman: Episode 4
# 18623       18623  Masterpiece                    Inside
#
#                                                      url  platform  score  \
# 17137                 /games/gone-home/xbox-one-20014361  Xbox One    9.5
# 17197            /games/rayman-legends/xbox-one-20008449  Xbox One    9.5
# ...

# %% [markdown]
# # Pandas plotting

# %%
reviews[reviews["platform"] == "Xbox One"]["score"]
# Out:
# 17137     9.5
# 17197     9.5
# 17295     9.0
# 17313     8.3
# 17314     7.0
#          ...
# 18591     9.2
# 18597     4.9
# 18602     7.4
# 18611     5.8
# 18623    10.0
# Name: score, Length: 208, dtype: float64

# %%
reviews[reviews["platform"] == "Xbox One"]["score"].plot(kind="hist")

# %%
reviews[reviews["platform"] == "PlayStation 4"]["score"].plot(kind="hist")

# %% [markdown]
# #  Part 2
# Analyzing Thanksgiving Dinner Trends

# %%
import pandas as pd
data = pd.read_csv("data_groupby_practice\\fivethirtyeight\\data\\thanksgiving-2015\\thanksgiving-2015-poll-data.csv", encoding="Latin-1")
#ies = pd.read_csv("data_groupby_practice\ign.csv")

data.head()

#\data_groupby_practice\fivethirtyeight\data\thanksgiving-2015
# Out:
#    RespondentID Do you celebrate Thanksgiving?  \
# 0    4337954960                            Yes
# 1    4337951949                            Yes
# 2    4337935621                            Yes
# 3    4337933040                            Yes
# 4    4337931983                            Yes
#
#   What is typically the main dish at your Thanksgiving dinner?  \
# 0                                             Turkey
# 1                                             Turkey
# 2                                             Turkey
# 3                                             Turkey
# 4                                           Tofurkey
#
#   What is typically the main dish at your Thanksgiving dinner? - Other (please specify)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# ...

# %%
# Do you celebrate Thanksgiving? column of data:
data['Do you celebrate Thanksgiving?'].unique()
# Out:
# array(['Yes', 'No'], dtype=object)

# %%
# Do people in Suburban areas serve more Cauliflower than people in Rural areas?
data.groupBy
data.groupby(['Captivity'])['Weight']

data.groupby(['How would you describe where you live?'])[]

Which of these side dishes aretypically served at your Thanksgiving dinner? Please select all that apply. - Cauliflower
# Out:
# Index(['RespondentID', 'Do you celebrate Thanksgiving?',
#        'What is typically the main dish at your Thanksgiving dinner?',
#        'What is typically the main dish at your Thanksgiving dinner? - Other (please specify)',
#        'How is the main dish typically cooked?',
#        'How is the main dish typically cooked? - Other (please specify)',
#        'What kind of stuffing/dressing do you typically have?',
#        'What kind of stuffing/dressing do you typically have? - Other (please specify)',
#        'What type of cranberry saucedo you typically have?',
#        'What type of cranberry saucedo you typically have? - Other (please specify)',
#        'Do you typically have gravy?',
#        'Which of these side dishes aretypically served at your Thanksgiving dinner? Please select all that apply. - Brussel sprouts',
#        'Which of these side dishes aretypically served at your Thanksgiving dinner? Please select all that apply. - Carrots',
# ...

# %%
# Do people in Suburban areas serve more Cauliflower than people in Rural areas?
data.groupby(['How would you describe where you live?'])['Which of these side dishes aretypically served at your Thanksgiving dinner? Please select all that apply. - Cauliflower'].count()
# Out:
# How would you describe where you live?
# Rural       12
# Suburban    52
# Urban       24
# Name: Which of these side dishes aretypically served at your Thanksgiving dinner? Please select all that apply. - Cauliflower, dtype: int64

# %%
data.groupby(['How would you describe where you live?',
              'Which of these side dishes aretypically served at your Thanksgiving dinner? Please select all that apply. - Cauliflower']).count()
# Out:
#                                                                                            RespondentID  \
# How would you describe where you live? Which of these side dishes aretypically served ...
# Rural                                  Cauliflower                                                   12
# Suburban                               Cauliflower                                                   52
# Urban                                  Cauliflower                                                   24
#
#                                                                                            Do you celebrate Thanksgiving?  \
# How would you describe where you live? Which of these side dishes aretypically served ...
# Rural                                  Cauliflower                                                                     12
# Suburban                               Cauliflower                                                                     52
# ...

# %%
foo = data.groupby(['How would you describe where you live?'])[
    'RespondentID',
    'Which of these side dishes aretypically served at your Thanksgiving dinner? Please select all that apply. - Cauliflower'].count()

# %%
foo2 = pd.DataFrame(foo)
print(type(foo2))
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %%
foo2
# Out:
#                                         RespondentID  \
# How would you describe where you live?
# Rural                                            216
# Suburban                                         496
# Urban                                            236
#
#                                         Which of these side dishes aretypically served at your Thanksgiving dinner? Please select all that apply. - Cauliflower
# How would you describe where you live?
# Rural                                                                                  12
# Suburban                                                                               52
# Urban                                                                                  24

# %%
foo2.loc[:,['Which of these side dishes aretypically served at your Thanksgiving dinner? Please select all that apply. - Cauliflower',
            'RespondentID']]
# Out:
#                                         Which of these side dishes aretypically served at your Thanksgiving dinner? Please select all that apply. - Cauliflower  \
# How would you describe where you live?
# Rural                                                                                  12
# Suburban                                                                               52
# Urban                                                                                  24
#
#                                         RespondentID
# How would you describe where you live?
# Rural                                            216
# Suburban                                         496
# Urban                                            236

# %%
def age_to_age_bracket(cols):
    num_coliflower = cols[0]
    total = cols[1]
    return num_coliflower/total
# Out:
#                                         RespondentID  \
# How would you describe where you live?
# Rural                                            216
# Suburban                                         496
# Urban                                            236
#
#                                         Which of these side dishes aretypically served at your Thanksgiving dinner? Please select all that apply. - Cauliflower
# How would you describe where you live?
# Rural                                                                                  12
# Suburban                                                                               52
# Urban                                                                                  24

# %%
# Updating the Age_Bracket column usingthe age_to_age_bracket function

#foo2['ratio'] = foo2[['Age',]].apply(age_to_age_bracket, axis = 1)
foo2['ratio'] = foo2.loc[:,['Which of these side dishes aretypically served at your Thanksgiving dinner? Please select all that apply. - Cauliflower',
            'RespondentID']].apply(age_to_age_bracket, axis = 1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-114-25935b6af154> in <module>
#       3 #foo2['ratio'] = foo2[['Age',]].apply(age_to_age_bracket, axis = 1)
#       4 foo2['ratio'] = foo2.loc[:,['Which of these side dishes aretypically served at your Thanksgiving dinner? Please select all that apply. - Cauliflower',
# ----> 5             'RespondentID']].apply(age_to_age_bracket, axis = 1)
#       6
#
# NameError: name 'age_to_age_bracket' is not defined

# %%
foo.transform(lambda x,y: x+1)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-82-178f468acd1e> in <module>
# ----> 1 foo.transform(lambda x,y: x+1)
#
# c:\users\administrator\documents\code_kaggle_plasticc\kaggle_plasticc\project\pymote_env\lib\site-packages\pandas\core\frame.py in transform(self, func, axis, *args, **kwargs)
#    6718         if axis == 1:
#    6719             return self.T.transform(func, *args, **kwargs).T
# -> 6720         return super().transform(func, *args, **kwargs)
#    6721
#    6722     def apply(
#
# c:\users\administrator\documents\code_kaggle_plasticc\kaggle_plasticc\project\pymote_env\lib\site-packages\pandas\core\generic.py in transform(self, func, *args, **kwargs)
#   10810     @Appender(_shared_docs["transform"] % dict(axis="", **_shared_doc_kwargs))
#   10811     def transform(self, func, *args, **kwargs):
# ...

# %%
filter = data['Which of these side dishes aretypically served at your Thanksgiving dinner? Please select all that apply. - Cauliflower']=="Cauliflower"
data[filter, ].count()
# Out:
# RespondentID                                                                             88
# Do you celebrate Thanksgiving?                                                           88
# What is typically the main dish at your Thanksgiving dinner?                             88
# What is typically the main dish at your Thanksgiving dinner? - Other (please specify)     5
# How is the main dish typically cooked?                                                   88
#                                                                                          ..
# How would you describe where you live?                                                   88
# Age                                                                                      88
# What is your gender?                                                                     88
# How much total combined money did all members of your HOUSEHOLD earn last year?          88
# ...

# %% [markdown]
# # Practice with pandas GroupBy class, and DataFrame.groupby()

# %% [markdown]
# ### following
# https://www.shanelynn.ie/summarising-aggregation-and-grouping-data-in-python-pandas/

# %%
import pandas as pd
import dateutil

# Load data from csv file
data = pd.read_csv('data_groupby_practice/phone_data.csv')
# Convert date from string to date times
data['date'] = data['date'].apply(dateutil.parser.parse, dayfirst=True)

# %%
data
# Out:
#      index                date  duration  item    month   network network_type
# 0        0 2014-10-15 06:58:00    34.429  data  2014-11      data         data
# 1        1 2014-10-15 06:58:00    13.000  call  2014-11  Vodafone       mobile
# 2        2 2014-10-15 14:46:00    23.000  call  2014-11    Meteor       mobile
# 3        3 2014-10-15 14:48:00     4.000  call  2014-11     Tesco       mobile
# 4        4 2014-10-15 17:27:00     4.000  call  2014-11     Tesco       mobile
# ..     ...                 ...       ...   ...      ...       ...          ...
# 825    825 2015-03-13 00:38:00     1.000   sms  2015-03     world        world
# 826    826 2015-03-13 00:39:00     1.000   sms  2015-03  Vodafone       mobile
# 827    827 2015-03-13 06:58:00    34.429  data  2015-03      data         data
# 828    828 2015-03-14 00:13:00     1.000   sms  2015-03     world        world
# 829    829 2015-03-14 00:16:00     1.000   sms  2015-03     world        world
#
# [830 rows x 7 columns]

# %%
# How many rows the dataset
data['index'].count()
# Out:
# 830

# %%
# What was the longest phone call / data entry?
data['duration'].max()
# Out:
# 10528.0

# %%
# How many seconds of phone calls are recorded in total
data[data['item']=='call']['duration'].sum()
# Out:
# 92321.0

# %%
# How many entries are there for each month?
data.groupby('month')['item'].count()
# Out:
# month
# 2014-11    230
# 2014-12    157
# 2015-01    205
# 2015-02    137
# 2015-03    101
# Name: item, dtype: int64

# %%
data['month'].value_counts()
# Out:
# 2014-11    230
# 2015-01    205
# 2014-12    157
# 2015-02    137
# 2015-03    101
# Name: month, dtype: int64

# %%
# Number of non-null unique network entries
data['network'].nunique()
# Out:
# 9

# %% [markdown]
# # groupby()

# %%
data.groupby(['month']).groups.keys()
# Out:
# dict_keys(['2014-11', '2014-12', '2015-01', '2015-02', '2015-03'])

# %%
data.groupby(['month']).head(3)
# observe there are 5 groups
# Out:
#      index                date  duration  item    month    network  \
# 0        0 2014-10-15 06:58:00    34.429  data  2014-11       data
# 1        1 2014-10-15 06:58:00    13.000  call  2014-11   Vodafone
# 2        2 2014-10-15 14:46:00    23.000  call  2014-11     Meteor
# 228    228 2014-11-13 06:58:00    34.429  data  2014-12       data
# 231    231 2014-11-14 06:58:00    34.429  data  2014-12       data
# 232    232 2014-11-14 17:24:00   124.000  call  2014-12  voicemail
# 381    381 2014-12-13 06:58:00    34.429  data  2015-01       data
# 386    386 2014-12-14 06:58:00    34.429  data  2015-01       data
# 389    389 2014-12-15 06:58:00    34.429  data  2015-01       data
# 577    577 2015-01-13 06:58:00    34.429  data  2015-02       data
# 586    586 2015-01-14 06:58:00    34.429  data  2015-02       data
# 594    594 2015-01-15 06:58:00    34.429  data  2015-02       data
# 729    729 2015-02-12 20:15:00    69.000  call  2015-03   landline
# 730    730 2015-02-12 20:51:00    86.000  call  2015-03      Tesco
# 731    731 2015-02-13 06:58:00    34.429  data  2015-03       data
#
#     network_type
# 0           data
# 1         mobile
# 2         mobile
# 228         data
# 231         data
# 232    voicemail
# 381         data
# 386         data
# 389         data
# 577         data
# 586         data
# 594         data
# 729     landline
# 730       mobile
# 731         data

# %%
# Get the first entry for each month
data.groupby(['month']).first()
# Out:
#          index                date  duration  item   network network_type
# month
# 2014-11      0 2014-10-15 06:58:00    34.429  data      data         data
# 2014-12    228 2014-11-13 06:58:00    34.429  data      data         data
# 2015-01    381 2014-12-13 06:58:00    34.429  data      data         data
# 2015-02    577 2015-01-13 06:58:00    34.429  data      data         data
# 2015-03    729 2015-02-12 20:15:00    69.000  call  landline     landline

# %%
# Get the sum of the durations per month
data.groupby(['month'])['duration'].sum()
# Out:
# month
# 2014-11    26639.441
# 2014-12    14641.870
# 2015-01    18223.299
# 2015-02    15522.299
# 2015-03    22750.441
# Name: duration, dtype: float64

# %%
# Get the number of unique dates / entries in each month
data.groupby(['month'])['date'].nunique()
# Out:
# month
# 2014-11    210
# 2014-12    147
# 2015-01    172
# 2015-02    125
# 2015-03     93
# Name: date, dtype: int64

# %%
# Get the number of dates / entries in each month
data.groupby(['month'])['date'].count()
# Out:
# month
# 2014-11    230
# 2014-12    157
# 2015-01    205
# 2015-02    137
# 2015-03    101
# Name: date, dtype: int64

# %%
data
# Out:
#      index                date  duration  item    month   network network_type
# 0        0 2014-10-15 06:58:00    34.429  data  2014-11      data         data
# 1        1 2014-10-15 06:58:00    13.000  call  2014-11  Vodafone       mobile
# 2        2 2014-10-15 14:46:00    23.000  call  2014-11    Meteor       mobile
# 3        3 2014-10-15 14:48:00     4.000  call  2014-11     Tesco       mobile
# 4        4 2014-10-15 17:27:00     4.000  call  2014-11     Tesco       mobile
# ..     ...                 ...       ...   ...      ...       ...          ...
# 825    825 2015-03-13 00:38:00     1.000   sms  2015-03     world        world
# 826    826 2015-03-13 00:39:00     1.000   sms  2015-03  Vodafone       mobile
# 827    827 2015-03-13 06:58:00    34.429  data  2015-03      data         data
# 828    828 2015-03-14 00:13:00     1.000   sms  2015-03     world        world
# 829    829 2015-03-14 00:16:00     1.000   sms  2015-03     world        world
#
# [830 rows x 7 columns]

# %%
# What is the sum of durations, for calls only, to each network
data[data['item']=='call'].groupby(['network'])[['duration']].sum()
# Out:
#            duration
# network
# Meteor       7200.0
# Tesco       13828.0
# Three       36464.0
# Vodafone    14621.0
# landline    18433.0
# voicemail    1775.0

# %%
# How many calls, sms, and data entries are in each month?
data.groupby(['month','item'])[['index']].count()
# Out:
#               index
# month   item
# 2014-11 call    107
#         data     29
#         sms      94
# 2014-12 call     79
#         data     30
#         sms      48
# 2015-01 call     88
#         data     31
#         sms      86
# 2015-02 call     67
#         data     31
#         sms      39
# 2015-03 call     47
#         data     29
#         sms      25

# %%
# How many calls, texts, and data are sent per month, split by network_type?
data.groupby(['month','network_type'],as_index=False)[['index']].count()
# Out:
#       month network_type  index
# 0   2014-11         data     29
# 1   2014-11     landline      5
# 2   2014-11       mobile    189
# 3   2014-11      special      1
# 4   2014-11    voicemail      6
# 5   2014-12         data     30
# 6   2014-12     landline      7
# 7   2014-12       mobile    108
# 8   2014-12    voicemail      8
# 9   2014-12        world      4
# 10  2015-01         data     31
# 11  2015-01     landline     11
# 12  2015-01       mobile    160
# 13  2015-01    voicemail      3
# 14  2015-02         data     31
# 15  2015-02     landline      8
# 16  2015-02       mobile     90
# 17  2015-02      special      2
# 18  2015-02    voicemail      6
# 19  2015-03         data     29
# 20  2015-03     landline     11
# 21  2015-03       mobile     54
# 22  2015-03    voicemail      4
# 23  2015-03        world      3

# %% [markdown]
# # the "agg()" function
# allows multiple statistics to be calculated

# %%
# Group the data frame by month and item and extract a number of stats from each group
data.groupby(
   ['month', 'item']
).agg(
    {
         'duration':sum,    # Sum duration per group
         'network_type': "count",  # get the count of networks
         'date': 'first'  # get the first date per group
    }
)
# Out:
#                duration  network_type                date
# month   item
# 2014-11 call  25547.000           107 2014-10-15 06:58:00
#         data    998.441            29 2014-10-15 06:58:00
#         sms      94.000            94 2014-10-16 22:18:00
# 2014-12 call  13561.000            79 2014-11-14 17:24:00
#         data   1032.870            30 2014-11-13 06:58:00
#         sms      48.000            48 2014-11-14 17:28:00
# 2015-01 call  17070.000            88 2014-12-15 20:03:00
#         data   1067.299            31 2014-12-13 06:58:00
#         sms      86.000            86 2014-12-15 19:56:00
# 2015-02 call  14416.000            67 2015-01-15 10:36:00
#         data   1067.299            31 2015-01-13 06:58:00
#         sms      39.000            39 2015-01-15 12:23:00
# 2015-03 call  21727.000            47 2015-02-12 20:15:00
#         data    998.441            29 2015-02-13 06:58:00
#         sms      25.000            25 2015-02-19 18:46:00

# %%
# You can also define functions inline using “lambda” functions to extract statistics
# Define the aggregation procedure outside of the groupby operation
aggregations = {
    'duration':'sum',
    'date': lambda x: max(x) - 1
}
data.groupby('month').agg(aggregations)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# c:\users\administrator\documents\code_kaggle_plasticc\kaggle_plasticc\project\pymote_env\lib\site-packages\pandas\core\groupby\ops.py in agg_series(self, obj, func)
#     662         try:
# --> 663             return self._aggregate_series_fast(obj, func)
#     664         except Exception:
#
# c:\users\administrator\documents\code_kaggle_plasticc\kaggle_plasticc\project\pymote_env\lib\site-packages\pandas\core\groupby\ops.py in _aggregate_series_fast(self, obj, func)
#     680         grouper = reduction.SeriesGrouper(obj, func, group_index, ngroups, dummy)
# --> 681         result, counts = grouper.get_result()
#     682         return result, counts
#
# pandas\_libs\reduction.pyx in pandas._libs.reduction.SeriesGrouper.get_result()
#
# pandas\_libs\reduction.pyx in pandas._libs.reduction.SeriesGrouper.get_result()
#
# c:\users\administrator\documents\code_kaggle_plasticc\kaggle_plasticc\project\pymote_env\lib\site-packages\pandas\core\groupby\groupby.py in <lambda>(x)
#     893         func = self._is_builtin_func(func)
# --> 894         f = lambda x: func(x, *args, **kwargs)
#     895
#
# <ipython-input-171-004522fede1b> in <lambda>(x)
#       4     'duration':'sum',
# ----> 5     'date': lambda x: max(x) - 1
#       6 }
#
# pandas\_libs\tslibs\c_timestamp.pyx in pandas._libs.tslibs.c_timestamp._Timestamp.__sub__()
#
# pandas\_libs\tslibs\c_timestamp.pyx in pandas._libs.tslibs.c_timestamp._Timestamp.__add__()
#
# ValueError: Cannot add integral value to Timestamp without freq.
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# c:\users\administrator\documents\code_kaggle_plasticc\kaggle_plasticc\project\pymote_env\lib\site-packages\pandas\core\groupby\generic.py in aggregate(self, func_or_funcs, *args, **kwargs)
#     862             try:
# --> 863                 return self._python_agg_general(func_or_funcs, *args, **kwargs)
#     864             except Exception:
#
# c:\users\administrator\documents\code_kaggle_plasticc\kaggle_plasticc\project\pymote_env\lib\site-packages\pandas\core\groupby\groupby.py in _python_agg_general(self, func, *args, **kwargs)
#     899             try:
# --> 900                 result, counts = self.grouper.agg_series(obj, f)
#     901                 output[name] = self._try_cast(result, obj, numeric_only=True)
#
# c:\users\administrator\documents\code_kaggle_plasticc\kaggle_plasticc\project\pymote_env\lib\site-packages\pandas\core\groupby\ops.py in agg_series(self, obj, func)
#     664         except Exception:
# --> 665             return self._aggregate_series_pure_python(obj, func)
#     666
#
# c:\users\administrator\documents\code_kaggle_plasticc\kaggle_plasticc\project\pymote_env\lib\site-packages\pandas\core\groupby\ops.py in _aggregate_series_pure_python(self, obj, func)
#     693         for label, group in splitter:
# --> 694             res = func(group)
#     695             if result is None:
#
# c:\users\administrator\documents\code_kaggle_plasticc\kaggle_plasticc\project\pymote_env\lib\site-packages\pandas\core\groupby\groupby.py in <lambda>(x)
#     893         func = self._is_builtin_func(func)
# --> 894         f = lambda x: func(x, *args, **kwargs)
#     895
#
# <ipython-input-171-004522fede1b> in <lambda>(x)
#       4     'duration':'sum',
# ----> 5     'date': lambda x: max(x) - 1
#       6 }
#
# pandas\_libs\tslibs\c_timestamp.pyx in pandas._libs.tslibs.c_timestamp._Timestamp.__sub__()
#
# pandas\_libs\tslibs\c_timestamp.pyx in pandas._libs.tslibs.c_timestamp._Timestamp.__add__()
#
# ValueError: Cannot add integral value to Timestamp without freq.
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-171-004522fede1b> in <module>
#       5     'date': lambda x: max(x) - 1
#       6 }
# ----> 7 data.groupby('month').agg(aggregations)
#
# c:\users\administrator\documents\code_kaggle_plasticc\kaggle_plasticc\project\pymote_env\lib\site-packages\pandas\core\groupby\generic.py in aggregate(self, arg, *args, **kwargs)
#    1453     @Appender(_shared_docs["aggregate"])
#    1454     def aggregate(self, arg=None, *args, **kwargs):
# -> 1455         return super().aggregate(arg, *args, **kwargs)
#    1456
#    1457     agg = aggregate
#
# c:\users\administrator\documents\code_kaggle_plasticc\kaggle_plasticc\project\pymote_env\lib\site-packages\pandas\core\groupby\generic.py in aggregate(self, func, *args, **kwargs)
#     227         func = _maybe_mangle_lambdas(func)
#     228
# --> 229         result, how = self._aggregate(func, _level=_level, *args, **kwargs)
#     230         if how is None:
#     231             return result
#
# c:\users\administrator\documents\code_kaggle_plasticc\kaggle_plasticc\project\pymote_env\lib\site-packages\pandas\core\base.py in _aggregate(self, arg, *args, **kwargs)
#     504
#     505                 try:
# --> 506                     result = _agg(arg, _agg_1dim)
#     507                 except SpecificationError:
#     508
#
# c:\users\administrator\documents\code_kaggle_plasticc\kaggle_plasticc\project\pymote_env\lib\site-packages\pandas\core\base.py in _agg(arg, func)
#     454                 result = OrderedDict()
#     455                 for fname, agg_how in arg.items():
# --> 456                     result[fname] = func(fname, agg_how)
#     457                 return result
#     458
#
# c:\users\administrator\documents\code_kaggle_plasticc\kaggle_plasticc\project\pymote_env\lib\site-packages\pandas\core\base.py in _agg_1dim(name, how, subset)
#     438                         "nested dictionary is ambiguous " "in aggregation"
#     439                     )
# --> 440                 return colg.aggregate(how, _level=(_level or 0) + 1)
#     441
#     442             def _agg_2dim(name, how):
#
# c:\users\administrator\documents\code_kaggle_plasticc\kaggle_plasticc\project\pymote_env\lib\site-packages\pandas\core\groupby\generic.py in aggregate(self, func_or_funcs, *args, **kwargs)
#     863                 return self._python_agg_general(func_or_funcs, *args, **kwargs)
#     864             except Exception:
# --> 865                 result = self._aggregate_named(func_or_funcs, *args, **kwargs)
#     866
#     867             index = Index(sorted(result), name=self.grouper.names[0])
#
# c:\users\administrator\documents\code_kaggle_plasticc\kaggle_plasticc\project\pymote_env\lib\site-packages\pandas\core\groupby\generic.py in _aggregate_named(self, func, *args, **kwargs)
#     995         for name, group in self:
#     996             group.name = name
# --> 997             output = func(group, *args, **kwargs)
#     998             if isinstance(output, (Series, Index, np.ndarray)):
#     999                 raise Exception("Must produce aggregated value")
#
# <ipython-input-171-004522fede1b> in <lambda>(x)
#       3 aggregations = {
#       4     'duration':'sum',
# ----> 5     'date': lambda x: max(x) - 1
#       6 }
#       7 data.groupby('month').agg(aggregations)
#
# pandas\_libs\tslibs\c_timestamp.pyx in pandas._libs.tslibs.c_timestamp._Timestamp.__sub__()
#
# pandas\_libs\tslibs\c_timestamp.pyx in pandas._libs.tslibs.c_timestamp._Timestamp.__add__()
#
# ValueError: Cannot add integral value to Timestamp without freq.

# %%
# applying multiple functions to columns or groups...
# Group the data frame by month and item and extract a number of stats from each group
data.groupby(
    ['month', 'item']
).agg(
    {
        # Find the min, max, and sum of the duration column
        'duration': [min, max, sum],
        # find the number of network type entries
        'network_type': "count",
        # minimum, first, and number of unique dates
        'date': [min, 'first', 'nunique']
    }
)
# Out:
#              duration                       network_type                date  \
#                   min        max        sum        count                 min
# month   item
# 2014-11 call    1.000   1940.000  25547.000          107 2014-10-15 06:58:00
#         data   34.429     34.429    998.441           29 2014-10-15 06:58:00
#         sms     1.000      1.000     94.000           94 2014-10-16 22:18:00
# 2014-12 call    2.000   2120.000  13561.000           79 2014-11-14 17:24:00
#         data   34.429     34.429   1032.870           30 2014-11-13 06:58:00
#         sms     1.000      1.000     48.000           48 2014-11-14 17:28:00
# 2015-01 call    2.000   1859.000  17070.000           88 2014-12-15 20:03:00
#         data   34.429     34.429   1067.299           31 2014-12-13 06:58:00
#         sms     1.000      1.000     86.000           86 2014-12-15 19:56:00
# 2015-02 call    1.000   1863.000  14416.000           67 2015-01-15 10:36:00
#         data   34.429     34.429   1067.299           31 2015-01-13 06:58:00
#         sms     1.000      1.000     39.000           39 2015-01-15 12:23:00
# 2015-03 call    2.000  10528.000  21727.000           47 2015-02-12 20:15:00
#         data   34.429     34.429    998.441           29 2015-02-13 06:58:00
#         sms     1.000      1.000     25.000           25 2015-02-19 18:46:00
#
#
#                            first nunique
# month   item
# 2014-11 call 2014-10-15 06:58:00     104
#         data 2014-10-15 06:58:00      29
#         sms  2014-10-16 22:18:00      79
# 2014-12 call 2014-11-14 17:24:00      76
#         data 2014-11-13 06:58:00      30
#         sms  2014-11-14 17:28:00      41
# 2015-01 call 2014-12-15 20:03:00      84
#         data 2014-12-13 06:58:00      31
#         sms  2014-12-15 19:56:00      58
# 2015-02 call 2015-01-15 10:36:00      67
#         data 2015-01-13 06:58:00      31
#         sms  2015-01-15 12:23:00      27
# 2015-03 call 2015-02-12 20:15:00      47
#         data 2015-02-13 06:58:00      29
#         sms  2015-02-19 18:46:00      17

# %% [markdown]
# # more recommended tutorials...
# * DataQuest Tutorial on Data Analysis: https://www.dataquest.io/blog/pandas-tutorial-python-2/
# * Chris Albon notes on Groups: https://chrisalbon.com/python/pandas_apply_operations_to_groups.html
# * Greg Reda Pandas Tutorial: http://www.gregreda.com/2013/10/26/working-with-pandas-dataframes/
